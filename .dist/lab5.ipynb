# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

data = np.random.rand(100)

labels = ["Class1" if x < 0.5 else "Class2" for x in data[:50]]

def euclidean_distance(x1, x2):
    return abs(x1 - x2)

def knn_classifier(train_data, train_labels, test_point, k):
    distances = [(euclidean_distance(test_point, train_data[i]), train_labels[i]) for i in range(len(train_data))]
    distances.sort(key=lambda x: x[0])
    k_nearest_neighbors = distances[:k]
    k_nearest_labels = [label for _, label in k_nearest_neighbors]
    return Counter(k_nearest_labels).most_common(1)[0][0]

train_data = data[:50]
train_labels = labels
test_data = data[50:]

k_values = [1, 2, 3, 4, 5, 20, 30]

print("\n--- K-Nearest Neighbors Classification ---")
print("Training dataset: First 50 points labeled based on the rule (x < 0.5 -> Class1, x > 0.5 -> Class2)")
print("Testing dataset: Remaining 50 points to be classified\n")

results = {}

for k in k_values:
    print(f"\nResults for k = {k}:")
    classified_labels = [knn_classifier(train_data, train_labels, test_point, k) for test_point in test_data]
    results[k] = classified_labels
    for i, label in enumerate(classified_labels, start=51):
        print(f"Point x{i} (value: {test_data[i - 51]:.4f}) is classified as {label}")
    print("\n")

print("Classification complete.\n")

for k in k_values:
    classified_labels = results[k]
    class1_points = [test_data[i] for i in range(len(test_data)) if classified_labels[i] == "Class1"]
    class2_points = [test_data[i] for i in range(len(test_data)) if classified_labels[i] == "Class2"]

    plt.figure(figsize=(6, 6))
    plt.scatter(train_data, [0] * len(train_data), c=["blue" if label == "Class1" else "red" for label in train_labels], marker='o', label="Training Data")
    plt.scatter(class1_points, [1] * len(class1_points), c="blue", label="Class1 (Test)", marker='x')
    plt.scatter(class2_points, [1] * len(class2_points), c="red", label="Class2 (Test)", marker='x')

    plt.title(f"K-NN Classification Results for k = {k}")
    plt.xlabel("Data Points")
    plt.ylabel("Classification Level")
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# --- K-Nearest Neighbors Classification ---
# Training dataset: First 50 points labeled based on the rule (x < 0.5 -> Class1, x > 0.5 -> Class2)
# Testing dataset: Remaining 50 points to be classified
#
#
# Results for k = 1:
# Point x51 (value: 0.7201) is classified as Class2
# Point x52 (value: 0.3401) is classified as Class1
# Point x53 (value: 0.7595) is classified as Class2
# Point x54 (value: 0.8306) is classified as Class2
# Point x55 (value: 0.8607) is classified as Class2
# Point x56 (value: 0.0827) is classified as Class1
# Point x57 (value: 0.4299) is classified as Class1
# Point x58 (value: 0.5165) is classified as Class2
# Point x59 (value: 0.7227) is classified as Class2
# Point x60 (value: 0.8609) is classified as Class2
# Point x61 (value: 0.9054) is classified as Class2
# Point x62 (value: 0.3789) is classified as Class1
# Point x63 (value: 0.2356) is classified as Class1
# Point x64 (value: 0.0101) is classified as Class1
# Point x65 (value: 0.9224) is classified as Class2
# Point x66 (value: 0.7833) is classified as Class2
# Point x67 (value: 0.4095) is classified as Class1
# Point x68 (value: 0.0518) is classified as Class1
# Point x69 (value: 0.8714) is classified as Class2
# Point x70 (value: 0.6787) is classified as Class2
# Point x71 (value: 0.6593) is classified as Class2
# Point x72 (value: 0.6278) is classified as Class2
# Point x73 (value: 0.7853) is classified as Class2
# Point x74 (value: 0.0167) is classified as Class1
# Point x75 (value: 0.7763) is classified as Class2
# Point x76 (value: 0.7779) is classified as Class2
# Point x77 (value: 0.0034) is classified as Class1
# Point x78 (value: 0.5966) is classified as Class2
# Point x79 (value: 0.4432) is classified as Class1
# Point x80 (value: 0.9398) is classified as Class2
# Point x81 (value: 0.0756) is classified as Class1
# Point x82 (value: 0.4004) is classified as Class1
# Point x83 (value: 0.8683) is classified as Class2
# Point x84 (value: 0.4842) is classified as Class1
# Point x85 (value: 0.6470) is classified as Class2
# Point x86 (value: 0.6962) is classified as Class2
# Point x87 (value: 0.1968) is classified as Class1
# Point x88 (value: 0.0394) is classified as Class1
# Point x89 (value: 0.0541) is classified as Class1
# Point x90 (value: 0.5652) is classified as Class2
# Point x91 (value: 0.3825) is classified as Class1
# Point x92 (value: 0.2512) is classified as Class1
# Point x93 (value: 0.4705) is classified as Class1
# Point x94 (value: 0.0244) is classified as Class1
# Point x95 (value: 0.1142) is classified as Class1
# Point x96 (value: 0.0471) is classified as Class1
# Point x97 (value: 0.9800) is classified as Class2
# Point x98 (value: 0.8554) is classified as Class2
# Point x99 (value: 0.6894) is classified as Class2
# Point x100 (value: 0.0729) is classified as Class1
#
#
#
# Results for k = 2:
# Point x51 (value: 0.7201) is classified as Class2
# Point x52 (value: 0.3401) is classified as Class1
# Point x53 (value: 0.7595) is classified as Class2
# Point x54 (value: 0.8306) is classified as Class2
# Point x55 (value: 0.8607) is classified as Class2
# Point x56 (value: 0.0827) is classified as Class1
# Point x57 (value: 0.4299) is classified as Class1
# Point x58 (value: 0.5165) is classified as Class2
# Point x59 (value: 0.7227) is classified as Class2
# Point x60 (value: 0.8609) is classified as Class2
# Point x61 (value: 0.9054) is classified as Class2
# Point x62 (value: 0.3789) is classified as Class1
# Point x63 (value: 0.2356) is classified as Class1
# Point x64 (value: 0.0101) is classified as Class1
# Point x65 (value: 0.9224) is classified as Class2
# Point x66 (value: 0.7833) is classified as Class2
# Point x67 (value: 0.4095) is classified as Class1
# Point x68 (value: 0.0518) is classified as Class1
# Point x69 (value: 0.8714) is classified as Class2
# Point x70 (value: 0.6787) is classified as Class2
# Point x71 (value: 0.6593) is classified as Class2
# Point x72 (value: 0.6278) is classified as Class2
# Point x73 (value: 0.7853) is classified as Class2
# Point x74 (value: 0.0167) is classified as Class1
# Point x75 (value: 0.7763) is classified as Class2
# Point x76 (value: 0.7779) is classified as Class2
# Point x77 (value: 0.0034) is classified as Class1
# Point x78 (value: 0.5966) is classified as Class2
# Point x79 (value: 0.4432) is classified as Class1
# Point x80 (value: 0.9398) is classified as Class2
# Point x81 (value: 0.0756) is classified as Class1
# Point x82 (value: 0.4004) is classified as Class1
# Point x83 (value: 0.8683) is classified as Class2
# Point x84 (value: 0.4842) is classified as Class1
# Point x85 (value: 0.6470) is classified as Class2
# Point x86 (value: 0.6962) is classified as Class2
# Point x87 (value: 0.1968) is classified as Class1
# Point x88 (value: 0.0394) is classified as Class1
# Point x89 (value: 0.0541) is classified as Class1
# Point x90 (value: 0.5652) is classified as Class2
# Point x91 (value: 0.3825) is classified as Class1
# Point x92 (value: 0.2512) is classified as Class1
# Point x93 (value: 0.4705) is classified as Class1
# Point x94 (value: 0.0244) is classified as Class1
# Point x95 (value: 0.1142) is classified as Class1
# Point x96 (value: 0.0471) is classified as Class1
# Point x97 (value: 0.9800) is classified as Class2
# Point x98 (value: 0.8554) is classified as Class2
# Point x99 (value: 0.6894) is classified as Class2
# Point x100 (value: 0.0729) is classified as Class1
#
#
#
# Results for k = 3:
# Point x51 (value: 0.7201) is classified as Class2
# Point x52 (value: 0.3401) is classified as Class1
# Point x53 (value: 0.7595) is classified as Class2
# Point x54 (value: 0.8306) is classified as Class2
# Point x55 (value: 0.8607) is classified as Class2
# Point x56 (value: 0.0827) is classified as Class1
# Point x57 (value: 0.4299) is classified as Class1
# Point x58 (value: 0.5165) is classified as Class2
# Point x59 (value: 0.7227) is classified as Class2
# Point x60 (value: 0.8609) is classified as Class2
# Point x61 (value: 0.9054) is classified as Class2
# Point x62 (value: 0.3789) is classified as Class1
# Point x63 (value: 0.2356) is classified as Class1
# Point x64 (value: 0.0101) is classified as Class1
# Point x65 (value: 0.9224) is classified as Class2
# Point x66 (value: 0.7833) is classified as Class2
# Point x67 (value: 0.4095) is classified as Class1
# Point x68 (value: 0.0518) is classified as Class1
# Point x69 (value: 0.8714) is classified as Class2
# Point x70 (value: 0.6787) is classified as Class2
# Point x71 (value: 0.6593) is classified as Class2
# Point x72 (value: 0.6278) is classified as Class2
# Point x73 (value: 0.7853) is classified as Class2
# Point x74 (value: 0.0167) is classified as Class1
# Point x75 (value: 0.7763) is classified as Class2
# Point x76 (value: 0.7779) is classified as Class2
# Point x77 (value: 0.0034) is classified as Class1
# Point x78 (value: 0.5966) is classified as Class2
# Point x79 (value: 0.4432) is classified as Class1
# Point x80 (value: 0.9398) is classified as Class2
# Point x81 (value: 0.0756) is classified as Class1
# Point x82 (value: 0.4004) is classified as Class1
# Point x83 (value: 0.8683) is classified as Class2
# Point x84 (value: 0.4842) is classified as Class1
# Point x85 (value: 0.6470) is classified as Class2
# Point x86 (value: 0.6962) is classified as Class2
# Point x87 (value: 0.1968) is classified as Class1
# Point x88 (value: 0.0394) is classified as Class1
# Point x89 (value: 0.0541) is classified as Class1
# Point x90 (value: 0.5652) is classified as Class2
# Point x91 (value: 0.3825) is classified as Class1
# Point x92 (value: 0.2512) is classified as Class1
# Point x93 (value: 0.4705) is classified as Class1
# Point x94 (value: 0.0244) is classified as Class1
# Point x95 (value: 0.1142) is classified as Class1
# Point x96 (value: 0.0471) is classified as Class1
# Point x97 (value: 0.9800) is classified as Class2
# Point x98 (value: 0.8554) is classified as Class2
# Point x99 (value: 0.6894) is classified as Class2
# Point x100 (value: 0.0729) is classified as Class1
#
#
#
# Results for k = 4:
# Point x51 (value: 0.7201) is classified as Class2
# Point x52 (value: 0.3401) is classified as Class1
# Point x53 (value: 0.7595) is classified as Class2
# Point x54 (value: 0.8306) is classified as Class2
# Point x55 (value: 0.8607) is classified as Class2
# Point x56 (value: 0.0827) is classified as Class1
# Point x57 (value: 0.4299) is classified as Class1
# Point x58 (value: 0.5165) is classified as Class2
# Point x59 (value: 0.7227) is classified as Class2
# Point x60 (value: 0.8609) is classified as Class2
# Point x61 (value: 0.9054) is classified as Class2
# Point x62 (value: 0.3789) is classified as Class1
# Point x63 (value: 0.2356) is classified as Class1
# Point x64 (value: 0.0101) is classified as Class1
# Point x65 (value: 0.9224) is classified as Class2
# Point x66 (value: 0.7833) is classified as Class2
# Point x67 (value: 0.4095) is classified as Class1
# Point x68 (value: 0.0518) is classified as Class1
# Point x69 (value: 0.8714) is classified as Class2
# Point x70 (value: 0.6787) is classified as Class2
# Point x71 (value: 0.6593) is classified as Class2
# Point x72 (value: 0.6278) is classified as Class2
# Point x73 (value: 0.7853) is classified as Class2
# Point x74 (value: 0.0167) is classified as Class1
# Point x75 (value: 0.7763) is classified as Class2
# Point x76 (value: 0.7779) is classified as Class2
# Point x77 (value: 0.0034) is classified as Class1
# Point x78 (value: 0.5966) is classified as Class2
# Point x79 (value: 0.4432) is classified as Class1
# Point x80 (value: 0.9398) is classified as Class2
# Point x81 (value: 0.0756) is classified as Class1
# Point x82 (value: 0.4004) is classified as Class1
# Point x83 (value: 0.8683) is classified as Class2
# Point x84 (value: 0.4842) is classified as Class1
# Point x85 (value: 0.6470) is classified as Class2
# Point x86 (value: 0.6962) is classified as Class2
# Point x87 (value: 0.1968) is classified as Class1
# Point x88 (value: 0.0394) is classified as Class1
# Point x89 (value: 0.0541) is classified as Class1
# Point x90 (value: 0.5652) is classified as Class2
# Point x91 (value: 0.3825) is classified as Class1
# Point x92 (value: 0.2512) is classified as Class1
# Point x93 (value: 0.4705) is classified as Class1
# Point x94 (value: 0.0244) is classified as Class1
# Point x95 (value: 0.1142) is classified as Class1
# Point x96 (value: 0.0471) is classified as Class1
# Point x97 (value: 0.9800) is classified as Class2
# Point x98 (value: 0.8554) is classified as Class2
# Point x99 (value: 0.6894) is classified as Class2
# Point x100 (value: 0.0729) is classified as Class1
#
#
#
# Results for k = 5:
# Point x51 (value: 0.7201) is classified as Class2
# Point x52 (value: 0.3401) is classified as Class1
# Point x53 (value: 0.7595) is classified as Class2
# Point x54 (value: 0.8306) is classified as Class2
# Point x55 (value: 0.8607) is classified as Class2
# Point x56 (value: 0.0827) is classified as Class1
# Point x57 (value: 0.4299) is classified as Class1
# Point x58 (value: 0.5165) is classified as Class2
# Point x59 (value: 0.7227) is classified as Class2
# Point x60 (value: 0.8609) is classified as Class2
# Point x61 (value: 0.9054) is classified as Class2
# Point x62 (value: 0.3789) is classified as Class1
# Point x63 (value: 0.2356) is classified as Class1
# Point x64 (value: 0.0101) is classified as Class1
# Point x65 (value: 0.9224) is classified as Class2
# Point x66 (value: 0.7833) is classified as Class2
# Point x67 (value: 0.4095) is classified as Class1
# Point x68 (value: 0.0518) is classified as Class1
# Point x69 (value: 0.8714) is classified as Class2
# Point x70 (value: 0.6787) is classified as Class2
# Point x71 (value: 0.6593) is classified as Class2
# Point x72 (value: 0.6278) is classified as Class2
# Point x73 (value: 0.7853) is classified as Class2
# Point x74 (value: 0.0167) is classified as Class1
# Point x75 (value: 0.7763) is classified as Class2
# Point x76 (value: 0.7779) is classified as Class2
# Point x77 (value: 0.0034) is classified as Class1
# Point x78 (value: 0.5966) is classified as Class2
# Point x79 (value: 0.4432) is classified as Class1
# Point x80 (value: 0.9398) is classified as Class2
# Point x81 (value: 0.0756) is classified as Class1
# Point x82 (value: 0.4004) is classified as Class1
# Point x83 (value: 0.8683) is classified as Class2
# Point x84 (value: 0.4842) is classified as Class1
# Point x85 (value: 0.6470) is classified as Class2
# Point x86 (value: 0.6962) is classified as Class2
# Point x87 (value: 0.1968) is classified as Class1
# Point x88 (value: 0.0394) is classified as Class1
# Point x89 (value: 0.0541) is classified as Class1
# Point x90 (value: 0.5652) is classified as Class2
# Point x91 (value: 0.3825) is classified as Class1
# Point x92 (value: 0.2512) is classified as Class1
# Point x93 (value: 0.4705) is classified as Class1
# Point x94 (value: 0.0244) is classified as Class1
# Point x95 (value: 0.1142) is classified as Class1
# Point x96 (value: 0.0471) is classified as Class1
# Point x97 (value: 0.9800) is classified as Class2
# Point x98 (value: 0.8554) is classified as Class2
# Point x99 (value: 0.6894) is classified as Class2
# Point x100 (value: 0.0729) is classified as Class1
#
#
#
# Results for k = 20:
# Point x51 (value: 0.7201) is classified as Class2
# Point x52 (value: 0.3401) is classified as Class1
# Point x53 (value: 0.7595) is classified as Class2
# Point x54 (value: 0.8306) is classified as Class2
# Point x55 (value: 0.8607) is classified as Class2
# Point x56 (value: 0.0827) is classified as Class1
# Point x57 (value: 0.4299) is classified as Class1
# Point x58 (value: 0.5165) is classified as Class1
# Point x59 (value: 0.7227) is classified as Class2
# Point x60 (value: 0.8609) is classified as Class2
# Point x61 (value: 0.9054) is classified as Class2
# Point x62 (value: 0.3789) is classified as Class1
# Point x63 (value: 0.2356) is classified as Class1
# Point x64 (value: 0.0101) is classified as Class1
# Point x65 (value: 0.9224) is classified as Class2
# Point x66 (value: 0.7833) is classified as Class2
# Point x67 (value: 0.4095) is classified as Class1
# Point x68 (value: 0.0518) is classified as Class1
# Point x69 (value: 0.8714) is classified as Class2
# Point x70 (value: 0.6787) is classified as Class2
# Point x71 (value: 0.6593) is classified as Class2
# Point x72 (value: 0.6278) is classified as Class2
# Point x73 (value: 0.7853) is classified as Class2
# Point x74 (value: 0.0167) is classified as Class1
# Point x75 (value: 0.7763) is classified as Class2
# Point x76 (value: 0.7779) is classified as Class2
# Point x77 (value: 0.0034) is classified as Class1
# Point x78 (value: 0.5966) is classified as Class2
# Point x79 (value: 0.4432) is classified as Class1
# Point x80 (value: 0.9398) is classified as Class2
# Point x81 (value: 0.0756) is classified as Class1
# Point x82 (value: 0.4004) is classified as Class1
# Point x83 (value: 0.8683) is classified as Class2
# Point x84 (value: 0.4842) is classified as Class1
# Point x85 (value: 0.6470) is classified as Class2
# Point x86 (value: 0.6962) is classified as Class2
# Point x87 (value: 0.1968) is classified as Class1
# Point x88 (value: 0.0394) is classified as Class1
# Point x89 (value: 0.0541) is classified as Class1
# Point x90 (value: 0.5652) is classified as Class2
# Point x91 (value: 0.3825) is classified as Class1
# Point x92 (value: 0.2512) is classified as Class1
# Point x93 (value: 0.4705) is classified as Class1
# Point x94 (value: 0.0244) is classified as Class1
# Point x95 (value: 0.1142) is classified as Class1
# Point x96 (value: 0.0471) is classified as Class1
# Point x97 (value: 0.9800) is classified as Class2
# Point x98 (value: 0.8554) is classified as Class2
# Point x99 (value: 0.6894) is classified as Class2
# Point x100 (value: 0.0729) is classified as Class1
#
#
#
# Results for k = 30:
# Point x51 (value: 0.7201) is classified as Class2
# Point x52 (value: 0.3401) is classified as Class1
# Point x53 (value: 0.7595) is classified as Class2
# Point x54 (value: 0.8306) is classified as Class2
# Point x55 (value: 0.8607) is classified as Class2
# Point x56 (value: 0.0827) is classified as Class1
# Point x57 (value: 0.4299) is classified as Class1
# Point x58 (value: 0.5165) is classified as Class2
# Point x59 (value: 0.7227) is classified as Class2
# Point x60 (value: 0.8609) is classified as Class2
# Point x61 (value: 0.9054) is classified as Class2
# Point x62 (value: 0.3789) is classified as Class1
# Point x63 (value: 0.2356) is classified as Class1
# Point x64 (value: 0.0101) is classified as Class1
# Point x65 (value: 0.9224) is classified as Class2
# Point x66 (value: 0.7833) is classified as Class2
# Point x67 (value: 0.4095) is classified as Class1
# Point x68 (value: 0.0518) is classified as Class1
# Point x69 (value: 0.8714) is classified as Class2
# Point x70 (value: 0.6787) is classified as Class2
# Point x71 (value: 0.6593) is classified as Class2
# Point x72 (value: 0.6278) is classified as Class2
# Point x73 (value: 0.7853) is classified as Class2
# Point x74 (value: 0.0167) is classified as Class1
# Point x75 (value: 0.7763) is classified as Class2
# Point x76 (value: 0.7779) is classified as Class2
# Point x77 (value: 0.0034) is classified as Class1
# Point x78 (value: 0.5966) is classified as Class2
# Point x79 (value: 0.4432) is classified as Class1
# Point x80 (value: 0.9398) is classified as Class2
# Point x81 (value: 0.0756) is classified as Class1
# Point x82 (value: 0.4004) is classified as Class1
# Point x83 (value: 0.8683) is classified as Class2
# Point x84 (value: 0.4842) is classified as Class1
# Point x85 (value: 0.6470) is classified as Class2
# Point x86 (value: 0.6962) is classified as Class2
# Point x87 (value: 0.1968) is classified as Class1
# Point x88 (value: 0.0394) is classified as Class1
# Point x89 (value: 0.0541) is classified as Class1
# Point x90 (value: 0.5652) is classified as Class2
# Point x91 (value: 0.3825) is classified as Class1
# Point x92 (value: 0.2512) is classified as Class1
# Point x93 (value: 0.4705) is classified as Class1
# Point x94 (value: 0.0244) is classified as Class1
# Point x95 (value: 0.1142) is classified as Class1
# Point x96 (value: 0.0471) is classified as Class1
# Point x97 (value: 0.9800) is classified as Class2
# Point x98 (value: 0.8554) is classified as Class2
# Point x99 (value: 0.6894) is classified as Class2
# Point x100 (value: 0.0729) is classified as Class1
#
#
# Classification complete.
